# %%
import make_overview_docx
import os

downloads_dir = os.path.join(os.path.expanduser("~"), "Downloads")
target_file = os.path.join(downloads_dir, "MediUnity_Project_Overview_and_Discussion.docx")
make_overview_docx.build_overview_document(target_file)
print("SUCCESS:", os.path.exists(target_file), target_file)
