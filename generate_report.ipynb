# %%
# Run generate_docx_report.py to generate MediUnity_Project_Report.docx
import generate_docx_report
generate_docx_report.create_report()

# %%
import sys
import subprocess
try:
    import docx
    print("docx version:", docx.__version__)
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "python-docx", "pillow"])
    import docx
    print("Installed docx version:", docx.__version__)
